# %% [markdown]
# <a href="https://colab.research.google.com/github/Zeljko12980/ai-learning-journey/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np;
print(np.__version__);
import matplotlib.pyplot as plt

x=np.linspace(0,10*np.pi,1000)
y=np.sin(x)

plt.plot(x,y)
# Out:
# 2.0.2

# %% [markdown]
# # New section

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

N = 20
# random data on the X-axis in (-5, 5)
x = np.random.random(N) * 10 - 5
# a line plus some noise
y = 0.5 * x - 1 + np.random.randn(N)

# plot the data
plt.scatter(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Random Linear Data with Noise")
plt.grid(True)
plt.show()

# %%
#create the model
model=nn.Linear(1,1)

#Loss and optimizer
criterion=nn.MSELoss()
optimizer=torch.optim.SGD(model.parameters(),lr=0.1)

x=x.reshape(N,1)
y=y.reshape(N,1)

inputs=torch.from_numpy(x.astype(np.float32))
targets=torch.from_numpy(y.astype(np.float32))

type(inputs)

#train the model
n_epochs=30
losses=[]

for it in range(n_epochs):
  optimizer.zero_grad()

  outputs=model(inputs)
  loss=criterion(outputs,targets)

  losses.append(loss.item())

  loss.backward()
  optimizer.step()

  print(f'Epoch {it+1}/{n_epochs}.Loss: {loss.item():.4f}')

#plot the loss per iteration
plt.plot(losses)
# Out:
# Epoch 1/30.Loss: 14.7254
# Epoch 2/30.Loss: 11.0611
# Epoch 3/30.Loss: 8.4309
# Epoch 4/30.Loss: 6.5362
# Epoch 5/30.Loss: 5.1668
# Epoch 6/30.Loss: 4.1741
# Epoch 7/30.Loss: 3.4525
# Epoch 8/30.Loss: 2.9266
# Epoch 9/30.Loss: 2.5425
# Epoch 10/30.Loss: 2.2614
# Epoch 11/30.Loss: 2.0553
# Epoch 12/30.Loss: 1.9039
# Epoch 13/30.Loss: 1.7926
# Epoch 14/30.Loss: 1.7106
# Epoch 15/30.Loss: 1.6502
# Epoch 16/30.Loss: 1.6056
# Epoch 17/30.Loss: 1.5727
# Epoch 18/30.Loss: 1.5484
# Epoch 19/30.Loss: 1.5304
# Epoch 20/30.Loss: 1.5171
# Epoch 21/30.Loss: 1.5072
# Epoch 22/30.Loss: 1.4999
# Epoch 23/30.Loss: 1.4945
# Epoch 24/30.Loss: 1.4905
# Epoch 25/30.Loss: 1.4875
# Epoch 26/30.Loss: 1.4853
# Epoch 27/30.Loss: 1.4836
# Epoch 28/30.Loss: 1.4824
# Epoch 29/30.Loss: 1.4815
# Epoch 30/30.Loss: 1.4809

# %% [markdown]
# # New section

# %%
#plot the graph
predicted=model(inputs).detach().numpy()
plt.scatter(x,y,label='Original data')
plt.plot(x,predicted, label='Fitted line',color='orange')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Random Linear Data with Noise")
plt.grid(True)
plt.legend()
plt.show()
